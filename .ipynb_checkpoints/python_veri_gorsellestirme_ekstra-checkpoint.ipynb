# %% [markdown]
# # Boxplot

# %% [markdown]
# total_bill: yemeğin toplam fiyatı (bahşiş ve vergi dahil)
#
# tip: bahşiş
#
# sex: ücreti ödeyen kişinin cinsiyeti (0=male, 1=female)
#
# smoker: grupta sigara içen var mı? (0=No, 1=Yes)
#
# day: gün (3=Thur, 4=Fri, 5=Sat, 6=Sun)
#
# time: ne zaman? (0=Day, 1=Night)
#
# size: grupta kaç kişi var?

# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %%
df = tips.copy()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df["time"].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %% [markdown]
# # grafik

# %%
sns.boxplot(x = df["total_bill"])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %% [markdown]
# # çaprazlamalar

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %% [markdown]
# # hangi günler daha fazla kazanırız

# %%
sns.boxplot(x = "day", y = "total_bill", data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # sabah mı akşiam mı

# %%
sns.boxplot(x = "time", y = "total_bill", data = df)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %% [markdown]
# # kişi sayısı kazanç

# %%
sns.boxplot(x = "size", y = "total_bill", data = df)
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.boxplot(x = "day", y = "total_bill",hue = "sex", data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Violin

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(y = "total_bill", kind = "violin", data = df)

# %%
sns.catplot(x = "day",y = "total_bill", kind = "violin", data = df);

# %%
sns.catplot(x = "sex",y = "total_bill", kind = "violin", data = df);

# %%
sns.catplot(x = "day",y = "total_bill",hue = "sex", kind = "violin", data = df);

# %% [markdown]
# # Korelasyon Grafiği

# %% [markdown]
# # Scatterplot

# %%
sns.scatterplot(x = "total_bill", y = "tip",data = df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Çaprazlamalar

# %%
sns.scatterplot(x = "total_bill", y = "tip",hue = "time",data = df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = "total_bill", y = "tip",hue = "time",style = "time",data = df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = "total_bill", y = "tip",hue = "day",style = "time",data = df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = "total_bill", y = "tip",hue = "size",size = "size",data = df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Doğrusal İlişki

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.lmplot(x = "total_bill",y = "tip", data = df);

# %%
sns.lmplot(x = "total_bill",y = "tip",hue = "smoker", data = df);

# %%
sns.lmplot(x = "total_bill",y = "tip",hue = "smoker",row = "time", data = df);

# %%
sns.lmplot(x = "total_bill",y = "tip",hue = "smoker",col = "time",row = "sex", data = df);

# %% [markdown]
# # scatterplot matrisi

# %%
iris = sns.load_dataset("iris")

# %%
df = iris.copy()

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.shape
# Out:
# (150, 5)

# %%
sns.pairplot(df);

# %%
sns.pairplot(df , hue = "species");

# %%
sns.pairplot(df , kind = "reg");

# %%
sns.pairplot(df , kind = "reg", hue = "species");

# %% [markdown]
# # Heatmap

# %%
flights = sns.load_dataset("flights")

# %%
df = flights.copy()

# %%
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df = df.pivot("month","year","passengers")

# %%
sns.heatmap(df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(df, annot = True, fmt = "d");

# %%
sns.heatmap(df, annot = True, fmt = "d", linewidths = 0.5);

# %% [markdown]
# # Çizgi Grafik

# %%
import seaborn as sns
fmri = sns.load_dataset("fmri")
df = fmri.copy()
df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
df.shape
# Out:
# (1064, 5)

# %%
df["timepoint"].describe()
# Out:
# count    1064.000000
# mean        9.000000
# std         5.479801
# min         0.000000
# 25%         4.000000
# 50%         9.000000
# 75%        14.000000
# max        18.000000
# Name: timepoint, dtype: float64

# %%
df["signal"].describe()
# Out:
# count    1064.000000
# mean        0.003540
# std         0.093930
# min        -0.255486
# 25%        -0.046070
# 50%        -0.013653
# 75%         0.024293
# max         0.564985
# Name: signal, dtype: float64

# %%
df.groupby("timepoint")["signal"].count()
# Out:
# timepoint
# 0     56
# 1     56
# 2     56
# 3     56
# 4     56
# 5     56
# 6     56
# 7     56
# 8     56
# 9     56
# 10    56
# 11    56
# 12    56
# 13    56
# 14    56
# 15    56
# 16    56
# 17    56
# 18    56
# Name: signal, dtype: int64

# %%
df.groupby("timepoint")["signal"].describe()
# Out:
#            count      mean       std       min       25%       50%       75%  \
# timepoint
# 0           56.0 -0.016662  0.028326 -0.064454 -0.039169 -0.018382  0.003539
# 1           56.0 -0.025002  0.030641 -0.082174 -0.046299 -0.024533 -0.005388
# 2           56.0 -0.012873  0.035440 -0.110565 -0.034944 -0.013183  0.009318
# 3           56.0  0.034446  0.058260 -0.089708 -0.001157  0.028430  0.061840
# 4           56.0  0.098194  0.092838 -0.046347  0.030912  0.070166  0.144911
# 5           56.0  0.137725  0.123353 -0.017946  0.042762  0.096535  0.211638
# 6           56.0  0.127515  0.137332 -0.054405  0.022409  0.068850  0.218919
# 7           56.0  0.075660  0.129704 -0.108222 -0.016252  0.032486  0.144781
# 8           56.0  0.013420  0.104216 -0.181241 -0.049453 -0.012834  0.030396
# 9           56.0 -0.032041  0.072728 -0.152929 -0.075693 -0.038496  0.008717
# 10          56.0 -0.053685  0.053148 -0.176453 -0.078893 -0.052906 -0.015302
# 11          56.0 -0.058194  0.053828 -0.238474 -0.093127 -0.045699 -0.022522
# 12          56.0 -0.052526  0.056991 -0.255486 -0.090391 -0.042294 -0.016239
# 13          56.0 -0.043532  0.053598 -0.224351 -0.069285 -0.031612 -0.012958
# 14          56.0 -0.033660  0.045983 -0.169312 -0.055110 -0.022165 -0.006797
# 15          56.0 -0.025880  0.039092 -0.134828 -0.050536 -0.018207  0.000486
# 16          56.0 -0.022414  0.035035 -0.131641 -0.041122 -0.020777 -0.001380
# 17          56.0 -0.021368  0.034797 -0.121574 -0.042946 -0.017070 -0.000026
# 18          56.0 -0.021867  0.036322 -0.103513 -0.046781 -0.020225 -0.002821
#
#                 max
# timepoint
# 0          0.074399
# 1          0.063558
# 2          0.077277
# 3          0.185581
# 4          0.346775
# 5          0.476055
# 6          0.564985
# 7          0.494787
# 8          0.337143
# 9          0.221716
# 10         0.089231
# 11         0.030528
# 12         0.055766
# 13         0.059510
# 14         0.050133
# 15         0.047102
# 16         0.057105
# 17         0.073757
# 18         0.090520

# %%
sns.lineplot(x = "timepoint", y = "signal" , data = df)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x = "timepoint", y = "signal" ,hue = "event", data = df)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x = "timepoint", y = "signal" ,hue = "event",style = "event", data = df);

# %%
(sns.lineplot(x = "timepoint"
             , y = "signal" 
             ,hue = "region"
             ,style = "event"
              , data = df));

# %% [markdown]
# # Basit Zaman Serisi

# %%
# !pip install pandas_datareader
import pandas_datareader as pr
# Out:
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Requirement already satisfied: pandas>=0.23 in c:\anaconda\lib\site-packages (from pandas_datareader) (1.4.2)
# Requirement already satisfied: lxml in c:\anaconda\lib\site-packages (from pandas_datareader) (4.8.0)
# Requirement already satisfied: requests>=2.19.0 in c:\anaconda\lib\site-packages (from pandas_datareader) (2.27.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\anaconda\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\anaconda\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\lib\site-packages (from pandas>=0.23->pandas_datareader) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\anaconda\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas_datareader) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\anaconda\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\anaconda\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2021.10.8)
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.10.0

# %%
df = pr.get_data_yahoo("AAPL", start = "2016-01-01", end = "2019-08-25")

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2016-01-04  26.342501  25.500000  25.652500  26.337500  270597600.0  24.151493
# 2016-01-05  26.462500  25.602501  26.437500  25.677500  223164000.0  23.546274
# 2016-01-06  25.592501  24.967501  25.139999  25.174999  273829600.0  23.085485
# 2016-01-07  25.032499  24.107500  24.670000  24.112499  324377600.0  22.111166
# 2016-01-08  24.777500  24.190001  24.637501  24.240000  283192000.0  22.228090

# %%
df.shape
# Out:
# (917, 6)

# %%
kapanis = df["Close"]

# %%
kapanis
# Out:
# Date
# 2016-01-04    26.337500
# 2016-01-05    25.677500
# 2016-01-06    25.174999
# 2016-01-07    24.112499
# 2016-01-08    24.240000
#                 ...
# 2019-08-19    52.587502
# 2019-08-20    52.590000
# 2019-08-21    53.160000
# 2019-08-22    53.115002
# 2019-08-23    50.660000
# Name: Close, Length: 917, dtype: float64

# %%
kapanis.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import pandas as pd

# %%
kapanis.index = pd.DatetimeIndex(kapanis.index)

# %%
kapanis.head()
# Out:
# Date
# 2016-01-04    26.337500
# 2016-01-05    25.677500
# 2016-01-06    25.174999
# 2016-01-07    24.112499
# 2016-01-08    24.240000
# Name: Close, dtype: float64

# %%
kapanis.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
